# %%
print("Jawad Jan")
a=5
b=6
# Out:
# Jawad Jan

# %% [markdown]
# **Addition**

# %%
a+b
# Out:
# 11

# %% [markdown]
# **Division**

# %%
a/b
# Out:
# 0.8333333333333334

# %% [markdown]
# **Multiplication**

# %%
a*b
# Out:
# 30

# %% [markdown]
# **Subtraction**

# %%
a-b
# Out:
# -1

# %% [markdown]
# **Jawad** **Jan**
